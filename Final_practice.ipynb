# %% [markdown]
# <a href="https://colab.research.google.com/github/shumyyla/TTDS/blob/master/Final_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x = [2,3,4,5,8,3,6,9]
y= [5,6,1,2,5,6,33,22]
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.plot(x,y)

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc169cceb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc169cc40d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc169cce8b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc169cc44f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc169cc4790>],
#  'means': []}

# %%
plt.hist(x)
# Out:
# (array([1., 2., 1., 0., 1., 1., 0., 0., 1., 1.]),
#  array([2. , 2.7, 3.4, 4.1, 4.8, 5.5, 6.2, 6.9, 7.6, 8.3, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.violinplot(y)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7fc1699c9880>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7fc1699c8f40>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7fc1699c9b50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7fc1699c9340>}

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import pandas as pd
  
df = pd.DataFrame([['Accuracy', 0.93, 0.78, 0.95, 0.98], ['Precision', 0.90, 0.85, 0.88, 0.94], ['Recall', 0.89, 0.84, 0.86, 0.93],
                   ['F1-Score', 0.94, 0.80, 0.85, 0.94]],
                  columns=['Models', 'CNN', 'DT', 'XGBoost', 'LSTM'])

print(df)
  
df.plot(x='Models',
        kind='bar',
        stacked=False,
        title='Comparison of Machine Learning techniques on Dataset',
        xlabel = 'Performance Metrics',
        ylabel = 'Performance Metric Value')

plt.xticks(rotation=0)

# Set X label to bold
ax = plt.gca()
ax.set_xlabel('Performance Metrics', fontweight='bold')
# Out:
#       Models   CNN    DT  XGBoost  LSTM
# 0   Accuracy  0.93  0.78     0.95  0.98
# 1  Precision  0.90  0.85     0.88  0.94
# 2     Recall  0.89  0.84     0.86  0.93
# 3   F1-Score  0.94  0.80     0.85  0.94
# Text(0.5, 0, 'Performance Metrics')

# %%
from seaborn.matrix import heatmap
df.plot(x='Models',
        kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-81f2f273c383> in <cell line: 2>()
#       1 from seaborn.matrix import heatmap
# ----> 2 df.plot(x='Models',
#       3         kind='scatter')
#
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
#     919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      68                 ax = plt.gca()
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
plt.scatter(x,y)

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x,y)

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.plot(x,y)
plt.xlabel('x axis',fontweight='bold')
plt.ylabel('y axis')
plt.title('simple bar graph')
plt.legend(['x label','y label'])

# %%
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]


fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot()
ax.plot(years,chemical_exports, label='chemical',marker='o')
ax.plot(years,medicine_exports,marker= '*',ls=':')


plt.xlabel('years')
plt.ylabel('exports')
xvlas = np.arange(2011,2022,2)
yvlas = np.linspace(0.80,0.98,10)
plt.xticks(xvlas)
plt.yticks(yvlas)
plt.legend(['chemical_exports','medicine_exports'])

# %%
x = np.array([22,33,44,5,5,6,6,6,6])
n = len(x)

stdd = (np.std(x, ddof=1))

# %%
print(stdd)
# Out:
# 14.737518259342188

# %%
np.sqrt(np.sum((x-np.mean(x))**2)/(n-1))
# Out:
# 14.737518259342188

# %%
pga = 0.8738738874343

print("{:.3f}".format(pga))
# Out:
# 0.874

# %%
import matplotlib.pyplot as plt
import pandas as pd
  
df = pd.DataFrame([['Accuracy', 0.93, 0.78, 0.95, 0.98], ['Precision', 0.90, 0.85, 0.88, 0.94], ['Recall', 0.89, 0.84, 0.86, 0.93],
                   ['F1-Score', 0.94, 0.80, 0.85, 0.94]],
                  columns=['Models', 'CNN', 'DT', 'XGBoost', 'LSTM'])

print(df)
  
df.plot(x='Models',
        kind='bar',
        stacked=False,
        title='Comparison of Machine Learning techniques on Dataset',
        xlabel = 'Performance Metrics',
        ylabel = 'Performance Metric Value')

plt.xticks(rotation=0)

# Set X label to bold
ax = plt.gca()
ax.set_xlabel('Performance Metrics', fontweight='bold')
# Out:
#       Models   CNN    DT  XGBoost  LSTM
# 0   Accuracy  0.93  0.78     0.95  0.98
# 1  Precision  0.90  0.85     0.88  0.94
# 2     Recall  0.89  0.84     0.86  0.93
# 3   F1-Score  0.94  0.80     0.85  0.94
# Text(0.5, 0, 'Performance Metrics')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Let us first generate the random marks of ten thousand students, with a mean of 60 and standard deviation of 10
mu = 60
sigma = 10
np.random.seed(54)
x = np.random.normal(mu, sigma, 10000)
x
# Out:
# array([41.47789255, 49.19001008, 60.78563826, ..., 67.12758548,
#        65.60509258, 60.75799144])

# %%
# Let us verify, whether the mean and std dev of above distribution `x` is 60 and 10 respectively
print("np.mean(x): ", np.mean(x))
print("np.std(x): ", np.std(x))
# Out:
# np.mean(x):  59.919552883530756
# np.std(x):  10.044223230060146

# %%
import numpy as np

# %%
import scipy
import statistics
import seaborn as sns
s = scipy.stats.skewnorm.rvs(20, size=10000)
print("Mean: ", statistics.mean(s))
print("Median: ", statistics.median(s))
print("Mode: ", statistics.mode(s))
print("Skew: ", scipy.stats.skew(s))

sns.displot(s, kde=True);
# Out:
# Mean:  0.7950298304994858
# Median:  0.6882808628985526
# Mode:  0.14045206361291815
# Skew:  0.9570943654395366

# %%
#Mesokurtic: kurtosis==3
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
mean = 25
stdev = 5
data = np.random.normal(loc=mean, scale=stdev,size=1000)
print('Kurtosis:', stats.kurtosis(data, fisher=False))
print("Skew: ", stats.skew(data))
#plt.hist(data, 50);
sns.displot(data);
# Out:
# Kurtosis: 3.16486592285462
# Skew:  0.005391892565682193

# %%
plt.hist(data,50)
# Out:
# (array([ 1.,  1.,  1.,  1.,  1.,  2.,  3.,  0.,  4.,  5., 10., 22.,  9.,
#          4., 20., 27., 29., 24., 39., 35., 46., 46., 57., 51., 54., 52.,
#         46., 59., 46., 48., 50., 32., 35., 22., 25., 20., 11., 15., 12.,
#          4.,  9.,  5.,  7.,  2.,  0.,  4.,  2.,  0.,  0.,  2.]),
#  array([ 8.46193091,  9.11362026,  9.76530961, 10.41699897, 11.06868832,
#         11.72037767, 12.37206703, 13.02375638, 13.67544573, 14.32713509,
#         14.97882444, 15.63051379, 16.28220315, 16.9338925 , 17.58558185,
#         18.2372712 , 18.88896056, 19.54064991, 20.19233926, 20.84402862,
#         21.49571797, 22.14740732, 22.79909668, 23.45078603, 24.10247538,
#         24.75416474, 25.40585409, 26.05754344, 26.7092328 , 27.36092215,
#         28.0126115 , 28.66430086, 29.31599021, 29.96767956, 30.61936892,
#         31.27105827, 31.92274762, 32.57443698, 33.22612633, 33.87781568,
#         34.52950504, 35.18119439, 35.83288374, 36.4845731 , 37.13626245,
# ...

# %%
# Correlation matrix of original data
weight = [86,82,74,73,62,61]
height = [157,168,170,181,191,185]
print("Correlation Matrix: \n", np.corrcoef(weight,height))
# Out:
# Correlation Matrix:
#  [[ 1.         -0.93701407]
#  [-0.93701407  1.        ]]
